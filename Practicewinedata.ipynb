# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("WineQT.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df[df['alcohol']>12.5]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 32              4.6             0.520         0.15            2.10      0.054
# 91              5.6             0.500         0.09            2.30      0.049
# 96              5.2             0.340         0.00            1.80      0.050
# 98              5.2             0.340         0.00            1.80      0.050
# 190             7.9             0.350         0.46            3.60      0.078
# 197            10.3             0.320         0.45            6.40      0.073
# 248            13.5             0.530         0.79            4.80      0.120
# 250             6.7             0.750         0.01            2.40      0.078
# 267            11.4             0.625         0.66            6.20      0.088
# 271             5.6             0.850         0.05            1.40      0.045
# 274            12.0             0.370         0.76            4.20      0.066
# ...

# %%
df[df['quality']>=8]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 190             7.9              0.35         0.46             3.6      0.078
# 197            10.3              0.32         0.45             6.4      0.073
# 271             5.6              0.85         0.05             1.4      0.045
# 310            12.6              0.31         0.72             2.2      0.072
# 321            11.3              0.62         0.67             5.2      0.086
# 340             9.4              0.30         0.56             2.8      0.080
# 349            10.7              0.35         0.53             2.6      0.070
# 352            10.7              0.35         0.53             2.6      0.070
# 419             5.0              0.42         0.24             2.0      0.060
# 747             9.1              0.40         0.50             1.8      0.071
# 769            10.0              0.26         0.54             1.9      0.083
# ...

# %%
greaterthan10=df.nlargest(10,'sulphates')
greaterthan10
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 103            9.2              0.52         1.00             3.4      0.610
# 59             8.6              0.49         0.28             1.9      0.110
# 64             8.6              0.49         0.28             1.9      0.110
# 514            7.1              0.31         0.30             2.2      0.053
# 161            8.9              0.59         0.50             2.0      0.337
# 11             7.8              0.61         0.29             1.6      0.114
# 240           12.5              0.28         0.54             2.3      0.082
# 454            8.9              0.29         0.35             1.9      0.067
# 738            8.5              0.46         0.59             1.4      0.414
# 934            9.1              0.76         0.68             1.7      0.414
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.groupby('quality')['alcohol'].mean()
# Out:
# quality
# 3     9.691667
# 4    10.260606
# 5     9.902277
# 6    10.655339
# 7    11.482634
# 8    11.937500
# Name: alcohol, dtype: float64

# %%
df.groupby('quality')['pH'].agg(['min','max'])
# Out:
#           min   max
# quality
# 3        3.16  3.55
# 4        2.74  3.90
# 5        2.88  3.74
# 6        2.86  4.01
# 7        2.92  3.78
# 8        2.88  3.72

# %%
df['quality'].value_counts()
# Out:
# quality
# 5    483
# 6    462
# 7    143
# 4     33
# 8     16
# 3      6
# Name: count, dtype: int64

# %%
df.groupby('quality')["alcohol"].mean()
# Out:
# quality
# 3     9.691667
# 4    10.260606
# 5     9.902277
# 6    10.655339
# 7    11.482634
# 8    11.937500
# Name: alcohol, dtype: float64

# %%
df.groupby('quality')['pH'].agg('min','max')
# Out:
# quality
# 3    3.16
# 4    2.74
# 5    2.88
# 6    2.86
# 7    2.92
# 8    2.88
# Name: pH, dtype: float64

# %%
df['quality'].value_counts()
# Out:
# quality
# 5    483
# 6    462
# 7    143
# 4     33
# 8     16
# 3      6
# Name: count, dtype: int64

# %%
df.groupby('quality')['pH'].agg(['min','max'])
# Out:
#           min   max
# quality
# 3        3.16  3.55
# 4        2.74  3.90
# 5        2.88  3.74
# 6        2.86  4.01
# 7        2.92  3.78
# 8        2.88  3.72

# %%
df['quality'].value_counts()
# Out:
# quality
# 5    483
# 6    462
# 7    143
# 4     33
# 8     16
# 3      6
# Name: count, dtype: int64

# %%
#find wines that have a pH above 3.5 and alcohol content higher than 10%
al=df[(df['pH']>3.5) & (df['alcohol']>10)]
al
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 32              4.6             0.520         0.15             2.1      0.054
# 51              8.8             0.410         0.64             2.2      0.093
# 52              6.8             0.785         0.00             2.4      0.104
# 66              5.0             1.020         0.04             1.4      0.045
# 87              8.2             1.330         0.00             1.7      0.081
# ...             ...               ...          ...             ...        ...
# 1131            6.1             0.715         0.10             2.6      0.053
# 1135            5.8             0.610         0.11             1.8      0.066
# 1137            5.4             0.740         0.09             1.7      0.089
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
#identify wines with sulphates greater than 0.8 but chlorides less than 0.05
cl=df[(df['sulphates']>0.8) & (df['chlorides']<0.05)]
cl
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 148             9.7             0.530         0.60             2.0      0.039
# 271             5.6             0.850         0.05             1.4      0.045
# 574             9.3             0.370         0.44             1.6      0.038
# 577             5.1             0.585         0.00             1.7      0.044
# 821             5.1             0.510         0.18             2.1      0.042
# 861             9.0             0.390         0.40             1.3      0.044
# 1000            8.1             0.290         0.36             2.2      0.048
# 1018            7.9             0.180         0.40             2.2      0.049
# 1052            5.3             0.470         0.11             2.2      0.048
# 1054            5.3             0.470         0.11             2.2      0.048
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
#find wines where the sum of free and total sulfur dioxide exceeds 100
w=[(df['free sulfur dioxide'] + df['total sulfur dioxide'])>100]
w
# Out:
# [0       False
#  1       False
#  2       False
#  3       False
#  4       False
#          ...
#  1138    False
#  1139    False
#  1140    False
#  1141    False
#  1142    False
#  Length: 1143, dtype: bool]

# %%
#find the correlation between alcohol content and wine quality

# %%
#determine if residual sugar influences wine quality using correlation

# %%
#find
