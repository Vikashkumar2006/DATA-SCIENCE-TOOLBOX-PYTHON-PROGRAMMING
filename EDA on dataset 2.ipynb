# %%
#import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("ObesityDataset.csv")
df.head()
df.sample(10) #To check any 10 rows sample
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 1048    Male  19.223259  1.706082   78.073528                            yes
# 813   Female  42.244750  1.768231   75.629310                            yes
# 1970  Female  25.908829  1.607734  102.305767                            yes
# 1863  Female  19.176140  1.666194  124.805868                            yes
# 338   Female  17.000000  1.600000   65.000000                             no
# 818     Male  18.900253  1.750359   79.828725                            yes
# 952   Female  17.807828  1.518067   55.822119                             no
# 575   Female  17.767432  1.743790   50.000000                             no
# 1589    Male  38.523646  1.765836  118.533246                            yes
# 1920  Female  25.919571  1.610488  102.174953                            yes
#
#      FAVC      FCVC       NCP        CAEC SMOKE      CH2O  SCC       FAF  \
# ...

# %%
#checking the columns
df.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
#examining the shape 
df.shape
# Out:
# (2111, 17)

# %%
#info using df.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
#describe the data
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
#check for null values/ missing values using df.isnull().sum()
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
#check for duplicate values using df.duplicate().sum()
df.duplicated().sum()
# Out:
# np.int64(24)

# %%
#delete the duplicate values using df.drop_duplicates()
df.drop_duplicates()
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
#creating histogram plots
df.hist(bins=25,figsize=(20,16))
plt.show()

# %%
#Draw frequency distribution of weight feature.Also draw kde.
sns.histplot(x="Weight",data=df,kde=True,color="red")
# Out:
# <Axes: xlabel='Weight', ylabel='Count'>

# %%
#Draw Age vs. Weight distribution (using which chart type ...?)
sns.scatterplot(x="Age",y="Weight",data=df,hue="Weight")
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
#Age vs FCVC
sns.scatterplot(x="Age",y="FCVC",data=df,hue="FCVC")
# Out:
# <Axes: xlabel='Age', ylabel='FCVC'>

# %%
#select all numeric columns from the dataset
numeric_cols= df.select_dtypes(include =['number'])
#computing correlation matrix
corr_matrix=numeric_cols.corr()
corr_matrix
# Out:
#              Age    Height    Weight      FCVC       NCP      CH2O       FAF  \
# Age     1.000000 -0.025958  0.202560  0.016291 -0.043944 -0.045304 -0.144938
# Height -0.025958  1.000000  0.463136 -0.038121  0.243672  0.213376  0.294709
# Weight  0.202560  0.463136  1.000000  0.216125  0.107469  0.200575 -0.051436
# FCVC    0.016291 -0.038121  0.216125  1.000000  0.042216  0.068461  0.019939
# NCP    -0.043944  0.243672  0.107469  0.042216  1.000000  0.057088  0.129504
# CH2O   -0.045304  0.213376  0.200575  0.068461  0.057088  1.000000  0.167236
# FAF    -0.144938  0.294709 -0.051436  0.019939  0.129504  0.167236  1.000000
# TUE    -0.296931  0.051912 -0.071561 -0.101135  0.036326  0.011965  0.058562
#
#              TUE
# Age    -0.296931
# Height  0.051912
# Weight -0.071561
# FCVC   -0.101135
# NCP     0.036326
# CH2O    0.011965
# FAF     0.058562
# TUE     1.000000

# %%
sns.heatmap(corr_matrix,cmap="Blues",annot=True,fmt='.2f')#.2f float value  ,  d->integer
# Out:
# <Axes: >

# %%
alchol=df["CALC"].value_counts()
alchol.values
labels=list(variety_count.index)
plt.pie(alchol.values,labels=labels,autopct='%.2f%%')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 3
#       1 alchol=df["CALC"].value_counts()
#       2 alchol.values
# ----> 3 labels=list(variety_count.index)
#       4 plt.pie(alchol.values,labels=labels,autopct='%.2f%%')
#       5 plt.show()
#
# NameError: name 'variety_count' is not defined
