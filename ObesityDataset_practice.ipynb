# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("ObesityDataset.csv")

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II

# %%
df.sample(10)
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 18    Female  30.000000  1.710000   82.000000                            yes
# 1333  Female  22.875223  1.624367   82.000000                            yes
# 1746    Male  25.758307  1.766547  115.458450                            yes
# 1473  Female  22.956845  1.618686   81.281578                            yes
# 979     Male  20.880161  1.674327   80.000000                            yes
# 1760    Male  31.490699  1.773521  120.209711                            yes
# 331     Male  17.000000  1.740000   56.000000                            yes
# 1958  Female  26.000000  1.643167  111.894229                            yes
# 332     Male  27.000000  1.850000   75.000000                            yes
# 572   Female  19.084967  1.768435   49.597765                             no
#
#      FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 18    yes  3.000000  4.000000  Frequently   yes  1.000000  no  0.000000
# 1333  yes  1.826885  1.000000   Sometimes    no  2.000000  no  0.000000
# 1746  yes  2.203962  3.000000   Sometimes    no  2.156870  no  1.289421
# 1473  yes  2.396265  1.073421   Sometimes    no  1.979833  no  0.022598
# 979   yes  2.000000  3.000000   Sometimes    no  2.000000  no  1.666390
# 1760  yes  2.777165  3.000000   Sometimes    no  2.106861  no  0.925941
# 331   yes  2.000000  3.000000   Sometimes    no  2.000000  no  2.000000
# 1958  yes  3.000000  3.000000   Sometimes    no  2.720050  no  0.000000
# 332   yes  2.000000  1.000000   Sometimes    no  2.000000  no  1.000000
# 572   yes  3.000000  3.725797   Sometimes    no  1.191401  no  2.000000
#
#            TUE       CALC                 MTRANS           NObeyesdad
# 18    0.000000         no             Automobile  Overweight_Level_II
# 1333  0.459274         no  Public_Transportation       Obesity_Type_I
# 1746  1.220767  Sometimes  Public_Transportation      Obesity_Type_II
# 1473  0.061282         no  Public_Transportation       Obesity_Type_I
# 979   1.443212         no  Public_Transportation  Overweight_Level_II
# 1760  0.291600  Sometimes             Automobile      Obesity_Type_II
# 331   1.000000         no  Public_Transportation        Normal_Weight
# 1958  0.127443  Sometimes  Public_Transportation     Obesity_Type_III
# 332   0.000000         no                Walking        Normal_Weight
# 572   1.000000  Sometimes  Public_Transportation  Insufficient_Weight

# %%
numeric_df=df.select_dtypes(include=['number'])
corr_matrix=numeric_df.corr()
print(corr_matrix)
# Out:
#              Age    Height    Weight      FCVC       NCP      CH2O       FAF  \
# Age     1.000000 -0.025958  0.202560  0.016291 -0.043944 -0.045304 -0.144938
# Height -0.025958  1.000000  0.463136 -0.038121  0.243672  0.213376  0.294709
# Weight  0.202560  0.463136  1.000000  0.216125  0.107469  0.200575 -0.051436
# FCVC    0.016291 -0.038121  0.216125  1.000000  0.042216  0.068461  0.019939
# NCP    -0.043944  0.243672  0.107469  0.042216  1.000000  0.057088  0.129504
# CH2O   -0.045304  0.213376  0.200575  0.068461  0.057088  1.000000  0.167236
# FAF    -0.144938  0.294709 -0.051436  0.019939  0.129504  0.167236  1.000000
# TUE    -0.296931  0.051912 -0.071561 -0.101135  0.036326  0.011965  0.058562
#
#              TUE
# Age    -0.296931
# Height  0.051912
# Weight -0.071561
# FCVC   -0.101135
# NCP     0.036326
# CH2O    0.011965
# FAF     0.058562
# TUE     1.000000

# %%
sns.heatmap(corr_matrix,annot=True,fmt=".2f",cmap="Purples")
# Out:
# <Axes: >

# %%
irir=sns.load_dataset('iris')

# %%
numeric_matrix=df.select_dtypes(include=['number'])
corr_matrix=numeric_df.corr()
print(corr_matrix)
# Out:
#              Age    Height    Weight      FCVC       NCP      CH2O       FAF  \
# Age     1.000000 -0.025958  0.202560  0.016291 -0.043944 -0.045304 -0.144938
# Height -0.025958  1.000000  0.463136 -0.038121  0.243672  0.213376  0.294709
# Weight  0.202560  0.463136  1.000000  0.216125  0.107469  0.200575 -0.051436
# FCVC    0.016291 -0.038121  0.216125  1.000000  0.042216  0.068461  0.019939
# NCP    -0.043944  0.243672  0.107469  0.042216  1.000000  0.057088  0.129504
# CH2O   -0.045304  0.213376  0.200575  0.068461  0.057088  1.000000  0.167236
# FAF    -0.144938  0.294709 -0.051436  0.019939  0.129504  0.167236  1.000000
# TUE    -0.296931  0.051912 -0.071561 -0.101135  0.036326  0.011965  0.058562
#
#              TUE
# Age    -0.296931
# Height  0.051912
# Weight -0.071561
# FCVC   -0.101135
# NCP     0.036326
# CH2O    0.011965
# FAF     0.058562
# TUE     1.000000

# %%
sns.heatmap(corr_matrix,annot=True,fmt=".2f",cmap="Purples")
# Out:
# <Axes: >
